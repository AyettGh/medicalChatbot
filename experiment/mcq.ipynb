# %%
from dotenv import load_dotenv
load_dotenv()  # take env variables from .env
# Out:
# False

# %%
RESPONSE_JSON= {
    "1":{
        "mcq":"multipule choice question",
        "options":{
            "a":"choice here",
            "b":"choice here",
            "c":"choice here",
            "d":"choice here",
        },
        "correct":"correct answer"
    },
        "2":{
        "mcq":"multipule choice question",
        "options":{
            "a":"choice here",
            "b":"choice here",
            "c":"choice here",
            "d":"choice here",
        },
        "correct":"correct answer"
    },
        "3":{
        "mcq":"multipule choice question",
        "options":{
            "a":"choice here",
            "b":"choice here",
            "c":"choice here",
            "d":"choice here",
        },
        "correct":"correct answer"
    },
}

# %%
#to chatgpt u have a text and make question with the number with a subject and tune is the dificulty level 
TEMPLATE="""
Text:{text}
You are an expert MCQ maler.Given above is a text,it is your job to \
Create a quiz of {number} multiple choice question for subject : {subject} students in {tone} tone.
Make sure the questions are not repeated and check the answers to be conforming the text.
Make sure to response your responses like RESPONSE_JSON and use it as a guide. \
Ensure to make {number} MCQs
### RESPONSE_JSON
{response_json}
"""

# %%
TEMPLATE2="""

You are an expert english grammarian and writer. Given a Multiple Choice Quiz for {subject} students.
You need to evaluate the complexity of the question and give a complete analysis of the quiz. Only use at max 50 words for
if the quiz is not at per with the cognitive and analytical abilities of the students. \
Update the quiz questions which needs to be changed and change the tone such that it perfectly fits the student
Quiz_MCQs:
{quiz}

Check from an expert English Writer of the above quiz:
"""

# %%
import sys
print(sys.executable)
# Out:
# d:\python\python.exe

# %%
import google.generativeai as genai

# Replace with your actual API key
API_KEY = "AIzaSyA4aRdMgRRQqGdj7QBoa0bF2fkmbHfuf6s"

# Configure
genai.configure(api_key=API_KEY)

# Test - List available models
print("Testing API Key...")
try:
    for model in genai.list_models():
        if 'generateContent' in model.supported_generation_methods:
            print(f"  ✓ {model.name}")
    print("\n✓ API Key works!")
except Exception as e:
    print(f"✗ Error: {e}")
# Out:
# Testing API Key...
#   ✓ models/gemini-2.5-pro-preview-03-25
#   ✓ models/gemini-2.5-flash-preview-05-20
#   ✓ models/gemini-2.5-flash
#   ✓ models/gemini-2.5-flash-lite-preview-06-17
#   ✓ models/gemini-2.5-pro-preview-05-06
#   ✓ models/gemini-2.5-pro-preview-06-05
#   ✓ models/gemini-2.5-pro
#   ✓ models/gemini-2.0-flash-exp
#   ✓ models/gemini-2.0-flash
#   ✓ models/gemini-2.0-flash-001
#   ✓ models/gemini-2.0-flash-exp-image-generation
#   ✓ models/gemini-2.0-flash-lite-001
#   ✓ models/gemini-2.0-flash-lite
#   ✓ models/gemini-2.0-flash-preview-image-generation
#   ✓ models/gemini-2.0-flash-lite-preview-02-05
#   ✓ models/gemini-2.0-flash-lite-preview
#   ✓ models/gemini-2.0-pro-exp
#   ✓ models/gemini-2.0-pro-exp-02-05
#   ✓ models/gemini-exp-1206
#   ✓ models/gemini-2.0-flash-thinking-exp-01-21
#   ✓ models/gemini-2.0-flash-thinking-exp
#   ✓ models/gemini-2.0-flash-thinking-exp-1219
#   ✓ models/gemini-2.5-flash-preview-tts
#   ✓ models/gemini-2.5-pro-preview-tts
#   ✓ models/learnlm-2.0-flash-experimental
#   ✓ models/gemma-3-1b-it
#   ✓ models/gemma-3-4b-it
#   ✓ models/gemma-3-12b-it
#   ✓ models/gemma-3-27b-it
#   ✓ models/gemma-3n-e4b-it
#   ✓ models/gemma-3n-e2b-it
#   ✓ models/gemini-flash-latest
#   ✓ models/gemini-flash-lite-latest
#   ✓ models/gemini-pro-latest
#   ✓ models/gemini-2.5-flash-lite
#   ✓ models/gemini-2.5-flash-image-preview
#   ✓ models/gemini-2.5-flash-image
#   ✓ models/gemini-2.5-flash-preview-09-2025
#   ✓ models/gemini-2.5-flash-lite-preview-09-2025
#   ✓ models/gemini-robotics-er-1.5-preview
#   ✓ models/gemini-2.5-computer-use-preview-10-2025
#
# ✓ API Key works!

# %%
import os
import json
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Set your API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyA4aRdMgRRQqGdj7QBoa0bF2fkmbHfuf6s"

# Initialize LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)



quiz_generation_prompt = PromptTemplate(
    input_variables=["text", "number", "subject", "tone", "response_json"],
    template=TEMPLATE
)


quiz_evaluation_prompt = PromptTemplate(
    input_variables=["subject", "quiz"],
    template=TEMPLATE2
)

# Build separate chains
quiz_chain = quiz_generation_prompt | llm | StrOutputParser()
review_chain = quiz_evaluation_prompt | llm | StrOutputParser()

# Read text
file_path = r"D:\medicalChatbot\data.txt"
with open(file_path, 'r') as file:
    TEXT = file.read()

NUMBER = 10
SUBJECT = "machine learning"
TONE = "simple"

# Step 1: Generate quiz
print("=" * 60)
print("STEP 1: GENERATING QUIZ...")
print("=" * 60)

quiz = quiz_chain.invoke({
    "text": TEXT,
    "number": NUMBER,
    "subject": SUBJECT,
    "tone": TONE,
    "response_json": json.dumps(RESPONSE_JSON)
})

print("\nGENERATED QUIZ:")
print(quiz)

# Step 2: Evaluate quiz
print("\n" + "=" * 60)
print("STEP 2: EVALUATING QUIZ...")
print("=" * 60)

evaluation = review_chain.invoke({
    "subject": SUBJECT,
    "quiz": quiz
})

print("\nEVALUATION:")
print(evaluation)

print("\n" + "=" * 60)
print("COMPLETED!")
print("=" * 60)
# Out:
# ============================================================
# STEP 1: GENERATING QUIZ...
# ============================================================
#
# GENERATED QUIZ:
# ```json
# {
#   "1": {
#     "mcq": "What is the primary objective of Machine Learning (ML) as defined in the provided text?",
#     "options": {
#       "a": "To explicitly program computers with step-by-step instructions for every task.",
#       "b": "To develop statistical algorithms that can learn from data and generalize to unseen data, performing tasks without explicit instructions.",
#       "c": "To create systems that strictly follow predefined rules without any adaptation.",
#       "d": "To replace human intelligence entirely with artificial, non-learning systems."
#     },
#     "correct": "b"
#   },
#   "2": {
#     "mcq": "According to the text, how is Deep Learning positioned within the broader fields of Machine Learning and Artificial Intelligence?",
#     "options": {
#       "a": "Deep Learning is a broader field that encompasses both Machine Learning and Artificial Intelligence.",
#       "b": "Deep Learning is a subset of Artificial Intelligence, but it is distinct from Machine Learning.",
#       "c": "Deep Learning is a subset of Machine Learning, which itself is a subset of Artificial Intelligence.",
#       "d": "Machine Learning and Deep Learning are synonymous terms for the same field within Artificial Intelligence."
#     },
#     "correct": "c"
#   },
#   "3": {
#     "mcq": "Which of the following fields is explicitly mentioned in the text as an application area for Machine Learning, indicating its direct relevance to medical students?",
#     "options": {
#       "a": "Computer gaming",
#       "b": "Agriculture",
#       "c": "Email filtering",
#       "d": "Medicine"
#     },
#     "correct": "d"
#   },
#   "4": {
#     "mcq": "Tom M. Mitchell's widely quoted definition of machine learning emphasizes which crucial aspect of a computer program?",
#     "options": {
#       "a": "Its ability to perform tasks only with explicit, detailed instructions.",
#       "b": "Its capacity to improve its performance at tasks with experience.",
#       "c": "Its inherent ability to understand human emotions and thought processes.",
#       "d": "Its reliance solely on pre-programmed knowledge without any learning."
#     },
#     "correct": "b"
#   },
#   "5": {
#     "mcq": "In Supervised Learning, what kind of 'signal' or 'feedback' is typically provided to the learning system?",
#     "options": {
#       "a": "No labels are given; the algorithm finds structure on its own.",
#       "b": "The computer interacts with a dynamic environment to maximize rewards.",
#       "c": "The computer is presented with example inputs and their desired outputs, given by a 'teacher'.",
#       "d": "The system generates its own supervisory signal from the data itself."
#     },
#     "correct": "c"
#   },
#   "6": {
#     "mcq": "Which of the following is identified as a central application of Unsupervised Machine Learning, particularly useful for finding hidden patterns in unlabelled medical datasets?",
#     "options": {
#       "a": "Classification",
#       "b": "Regression",
#       "c": "Clustering",
#       "d": "Reinforcement"
#     },
#     "correct": "c"
#   },
#   "7": {
#     "mcq": "While Machine Learning primarily focuses on prediction based on known properties learned from training data, what is the main focus of Data Mining, according to the text?",
#     "options": {
#       "a": "Minimization of loss functions.",
#       "b": "The discovery of previously unknown properties in the data.",
#       "c": "Reproducing known knowledge with high accuracy.",
#       "d": "Generalizing from experience to new, unseen examples."
#     },
#     "correct": "b"
#   },
#   "8": {
#     "mcq": "Who is credited with coining the term 'machine learning' in 1959, an important milestone in the field's history?",
#     "options": {
#       "a": "Donald Hebb",
#       "b": "Walter Pitts",
#       "c": "Arthur Samuel",
#       "d": "Geoffrey Hinton"
#     },
#     "correct": "c"
#   },
#   "9": {
#     "mcq": "The text mentions that k-means clustering can be utilized for data compression, for instance, in image compression. In the context of machine learning paradigms, k-means clustering is a prime example of which type of learning?",
#     "options": {
#       "a": "Supervised learning",
#       "b": "Reinforcement learning",
#       "c": "Semi-supervised learning",
#       "d": "Unsupervised learning"
#     },
#     "correct": "d"
#   },
#   "10": {
#     "mcq": "In the theory of machine learning, what is the consequence if a model's hypothesis is *too complex* relative to the function underlying the data, particularly when considering its performance on new, unseen data?",
#     "options": {
#       "a": "The model has underfitted the data, leading to high training error.",
#       "b": "The model is subject to overfitting, resulting in poorer generalization.",
#       "c": "The training error increases, but generalization significantly improves.",
#       "d": "The model achieves perfect accuracy on both training and unseen data."
#     },
#     "correct": "b"
#   }
# }
# ```
#
# ============================================================
# STEP 2: EVALUATING QUIZ...
# ============================================================
#
# EVALUATION:
# This quiz is grammatically excellent, clear, and well-structured. Questions are precise, and options are distinct and relevant to the medical field where highlighted. The vocabulary is appropriate for intelligent students, assuming foundational ML concepts were covered. No updates are needed; the quiz is well-designed.
#
# ============================================================
# COMPLETED!
# ============================================================
